# %%
#The goal is to implement ORB feature descriptor in Pytorch based on the skimage implementation https://github.com/scikit-image/scikit-image/blob/master/skimage/feature/orb.py#L22

# %%
import torch
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import skimage.transform

# %%
def pyramid_gaussian(image, max_layer=-1, downscale=2, sigma=None, order=1,
                     mode='reflect', cval=0, multichannel=False,
                     preserve_range=False):
    image=torch.FloatTensor(image)
    layer = 0
    current_shape = image.shape

    prev_layer_image = image
    yield image

# %%
im=np.load('microscop_org.npy')
plt.imshow(im)
